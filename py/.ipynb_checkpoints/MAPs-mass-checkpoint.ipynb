# %%
import numpy as np
import matplotlib.pyplot as plt
import apogee.select as apsel
import apogee.tools.read as apread
from galpy.util import bovy_coords
from galpy.orbit import Orbit, Orbits
from galpy.potential import MWPotential2014
from galpy.potential import SolidBodyRotationWrapperPotential, DehnenSmoothWrapperPotential, \
   CosmphiDiskPotential, DehnenBarPotential, LogarithmicHaloPotential, SpiralArmsPotential
import mwdust
import gaia_tools
import tqdm
from gaia_tools import xmatch
from astropy.io import fits
import gaia_tools.load as gload
import dill as pickle
import multiprocessing
import os
import emcee
import scipy.optimize as op
from scipy import interpolate
from scipy.stats import gaussian_kde
import utils
import sys
from isodist import FEH2Z, Z2FEH
import corner
params = {'axes.labelsize': 14, 'xtick.labelsize': 12, 'ytick.labelsize': 12, 'text.usetex': True, 'lines.linewidth': 1,
          'axes.titlesize': 14, 'font.family': 'serif'}
plt.rcParams.update(params)

columnwidth = 240./72.27
textwidth = 504.0/72.27

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload

# %%
#load allStar (main sample w/ Leung & Bovy distances, removing duplicates)
allstar = apread.allStar(main=True, rmdups=True,use_astroNN_distances=True)
print(str(len(allstar))+' stars in total sample.')
# Out:
# /anaconda3/lib/python3.7/site-packages/apogee-1.-py3.7.egg/apogee/tools/read.py:1240: UserWarning: Adding distances from Leung & Bovy (2019b)
#   warnings.warn("Adding distances from Leung & Bovy (2019b)")
#
# Removing duplicates (might take a while) and caching the duplicate-free file ... (file not cached if use_astroNN=True)
# 100%|██████████| 43720/43720 [00:03<00:00, 11721.03it/s]
# 137748 stars in total sample.

# %%
#load selection function/statIndx/effsel if they exist, if not, evaluate and pickle (set force to True for brute force re-evaluation)
force = False
if os.path.exists('../sav/apogeeCombinedSF.dat') and not force:
    with open('../sav/apogeeCombinedSF.dat', 'rb') as f:
        apo = pickle.load(f)
else:
    apo = apsel.apogeeCombinedSelect()
    del apo._specdata, apo._photdata
    with open('../sav/apogeeCombinedSF.dat', 'wb') as f:
        pickle.dump(apo, f)
        
#determine statistical sample and pickle file
if os.path.exists('../sav/statIndx.dat') and not force:
    with open('../sav/statIndx.dat', 'rb') as f:
        statIndx = pickle.load(f)
else:
    statIndx = apo.determine_statistical(allstar)
    with open('../sav/statIndx.dat', 'wb') as f:
        pickle.dump(statIndx, f)

# %%
# have a look at low [Fe/H] DR14 sample
fig = plt.figure()
fig.set_size_inches(1.5*columnwidth, columnwidth)
mask = allstar[statIndx]['FE_H'] < -1.
plt.scatter(allstar[statIndx]['FE_H'], allstar[statIndx]['MG_FE'], s=0.1, color='Black', lw=0., rasterized=True)
plt.scatter(-9999,-9999,s=10,color='Black', label=r'APOGEE DR14')
plt.scatter(allstar[statIndx][mask]['FE_H'], allstar[statIndx][mask]['MG_FE'], s=5, color='#BB5566', label=r'low $\mathrm{[Fe/H]}$')

plt.legend(loc=1)

plt.xlim(-2.,0.5)
plt.ylim(-0.2,0.6)
fig.tight_layout()
plt.xlabel(r'$\mathrm{[Fe/H]}$')
plt.ylabel(r'$\mathrm{[Mg/Fe]}$')
# Out:
# Text(9.575749265449875, 0.5, '$\\mathrm{[Mg/Fe]}$')

# %%
bins = np.arange(-1.6,-1.,0.2)
plt.hist(allstar[statIndx]['FE_H'], bins=bins)
# Out:
# (array([175., 319., 375.]),
#  array([-1.6, -1.4, -1.2, -1. ]),
#  <a list of 3 Patch objects>)

# %%
def _calc_effsel_onelocation(i): 
    loc = apo._locations[i]
    if np.sum([np.nansum(apo._nspec_short[i]),np.nansum(apo._nspec_medium[i]),np.nansum(apo._nspec_long[i])]) < 1.:
        effsel = np.zeros(len(ds))
    elif apo.JKmin(loc) >= 0.5:
        effsel = apof(loc, ds, MH=H, JK0=(J-K))*apo.area(loc)
    elif apo.JKmin(loc) < 0.5:
        effsel = apof(loc, ds, MH=p3H, JK0=(p3J-p3K))*apo.area(loc)
    return effsel
force = False
nsamples=2000
ndistmods=301
minmax_distmods=[7.,19.]
nthreads = int(multiprocessing.cpu_count()//2)
isorec = utils.generate_isogrid()
dmap = mwdust.Combined15()
apof = apsel.apogeeEffectiveSelect(apo, dmap3d=dmap)

if os.path.exists('../essf/effsel_grid_fehbins_inclArea.npy') and not force:
    sys.stdout.write('\r'+"loading saved effective selection function for APOGEE fields...\r")
    sys.stdout.flush()
    with open('../essf/effsel_grid_fehbins_inclArea.npy', 'rb') as f:
        outarea = np.load(f)
else:
    sys.stdout.write('\r'+"calculating effective selection function for APOGEE fields...\r")
    sys.stdout.flush()
    out = np.zeros((len(bins)-1,len(apo._locations),ndistmods))
    for i in range(len(bins)-1):
        niso, p3niso = utils.APOGEE_iso_samples(nsamples, isorec, fehrange=[bins[i], bins[i+1]])
        H, J, K = niso['H'], niso['J'], niso['K']
        p3H, p3J, p3K = p3niso['H'], p3niso['J'], p3niso['K']
        distmods = np.linspace(minmax_distmods[0], minmax_distmods[1], ndistmods)
        ds = 10.**(distmods/5-2)
        with multiprocessing.Pool(nthreads) as p:
            outarea = list(tqdm.tqdm(p.imap(_calc_effsel_onelocation, range(0,len(apo._locations))), total=len(apo._locations)))
        out[i] = np.array(outarea)
    with open('../essf/effsel_grid_fehbins_inclArea.dat', 'wb') as f:
        np.save(out, f)
# Out:
# 100%|██████████| 71/71 [00:02<00:00, 31.20it/s]
# calculating effective selection function for APOGEE fields...
#   1%|          | 6/667 [00:38<3:35:57, 19.60s/it]Process ForkPoolWorker-2:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-1:
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /anaconda3/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     758             try:
# --> 759                 item = self._items.popleft()
#     760             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-bacebe58915e> in <module>
#      33         ds = 10.**(distmods/5-2)
#      34         with multiprocessing.Pool(nthreads) as p:
# ---> 35             outarea = list(tqdm.tqdm(p.imap(_calc_effsel_onelocation, range(0,len(apo._locations))), total=len(apo._locations)))
#      36         out[i] = np.array(outarea)
#      37     with open('../essf/effsel_grid_fehbins_inclArea.dat', 'wb') as f:
#
# /anaconda3/lib/python3.7/site-packages/tqdm/_tqdm.py in __iter__(self)
#     977 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     978
# --> 979             for obj in iterable:
#     980                 yield obj
#     981                 # Update and possibly print the progressbar.
#
# /anaconda3/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     761                 if self._index == self._length:
#     762                     raise StopIteration from None
# --> 763                 self._cond.wait(timeout)
#     764                 try:
#     765                     item = self._items.popleft()
#
# /anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
niso, p3niso = utils.APOGEE_iso_samples(nsamples, isorec, fehrange=[-1.6, 1.])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-c9475ba31208> in <module>
# ----> 1 niso, p3niso = utils.APOGEE_iso_samples(nsamples, isorec, fehrange=[-1.6, 1.])
#
# ~/Documents/gaia/enceladus-mass/py/utils.py in APOGEE_iso_samples(nsamples, rec, fehrange)
#     198     trec = np.copy(rec)
#     199     mask = (trec['J']-trec['K'] > 0.5)  & (Z2FEH(trec['Z']) < fehrange[0]) & (Z2FEH(trec['Z']) > fehrange[1]) & (trec['M_ini'] > 0.75) & (trec['logg'] < 3.) & (trec['logg'] > 1.)
# --> 200     niso = sampleiso(nsamples,trec[mask], return_iso=True)
#     201     mask = (trec['J']-trec['K'] > 0.3001)  & (Z2FEH(trec['Z']) < fehrange[0]) & (Z2FEH(trec['Z']) > fehrange[1]) & (trec['M_ini'] > 0.75) & (trec['logg'] < 3.) & (trec['logg'] > 1.)
#     202     p3niso = sampleiso(nsamples,trec[mask], return_iso=True)
#
# ~/Documents/gaia/enceladus-mass/py/utils.py in sampleiso(N, iso, return_inds, return_iso)
#     168     weights = iso['deltaM']*(10**(iso['logageyr']-9)/iso['Z'])
#     169     sort = np.argsort(weights)
# --> 170     tinter = interp1d(np.cumsum(weights[sort])/np.sum(weights), range(len(weights[sort])), kind='linear')
#     171     randinds = np.round(tinter(np.random.rand(N))).astype(np.int64)
#     172     if return_inds:
#
# /anaconda3/lib/python3.7/site-packages/scipy/interpolate/interpolate.py in __init__(self, x, y, kind, axis, copy, bounds_error, fill_value, assume_sorted)
#     468         # Interpolation goes internally along the first axis
#     469         self.y = y
# --> 470         self._y = self._reshape_yi(self.y)
#     471         self.x = x
#     472         del y, x  # clean up namespace to prevent misuse; use attributes
#
# /anaconda3/lib/python3.7/site-packages/scipy/interpolate/polyint.py in _reshape_yi(self, yi, check)
#     109                                            self._y_extra_shape[:-self._y_axis])
#     110             raise ValueError("Data must be of shape %s" % ok_shape)
# --> 111         return yi.reshape((yi.shape[0], -1))
#     112
#     113     def _set_yi(self, yi, xi=None, axis=None):
#
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)

# %%
mask = (trec['J']-trec['K'] > 0.5)  & (Z2FEH(trec['Z'])  fehrange[0]) & (Z2FEH(trec['Z']) > fehrange[1]) & (trec['M_ini'] > 0.75) & (trec['logg'] < 3.) & (trec['logg'] > 1.)
